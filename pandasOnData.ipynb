# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

data = pd.read_csv('./belt.csv',dayfirst=True, index_col='Date')
runs = pd.read_csv('./runs.csv',dayfirst=True, index_col='date')
#print data.head()
print runs.head()
#runs['e'] = pd.Series(np.random.randn(len(runs)))
data['kmrun1monthago'] = pd.Series(np.random.randn(len(data)))
data['kmrun1monthago'] =data['kmrun1monthago'] * 0

#date(year, month, day)¶

a = "05/12/2016".split('/')
d = datetime.date(int(a[2]),int(a[1]),int(a[0]))
print d.isocalendar()


data['Non Fat kg'].plot()
data.head()
#for i in range(len(data)):
#    data[]

#data.head()
#np.random.randn(len(runs))
# Out:
#             Km run   hrs run  Weight Avg  belt
# date
# 04/01/2016   10.02  1.000000        77.0   NaN
# 11/01/2016   12.00  1.333333        77.0   NaN
# 18/01/2016   12.10  1.233333        78.0   NaN
# 25/01/2016   34.31  3.366667        77.3  86.0
# 01/02/2016   45.94  4.966667        76.4  87.0
# (2016, 49, 1)
#            belt  navel  weight     Fat kg  Non Fat kg US Navy Fat %  \
# Date
# 11-Jan-14  94.0  88.00    78.0  14.638640   63.361360   18.76748673
# 21-Nov-14  97.0  91.00    83.0  17.390785   65.609215   20.95275321
# 21-Jan-16  88.8  85.00    78.0  12.828184   65.171816   16.44639018
# 28-Jan-16  86.0  79.75    77.6   9.313025   68.286975   12.00132125
# 29-Jan-16  85.0  79.00    77.3   8.750996   68.549004   11.32082299
#
#            kmrun1monthago
# Date
# 11-Jan-14             NaN
# 21-Nov-14             NaN
# 21-Jan-16             NaN
# 28-Jan-16             NaN
# 29-Jan-16             NaN

# %%
#df = pd.DataFrame(np.random.randn(6,4), columns=list('ABCD'))
#np.random.randn(6,4)
df = pd.DataFrame([[2,3,5,6],[23,5,6,6],[23,5,6,6],[23,5,6,6]],index =['aa','bb','cc','dd'] , columns=list('ABCD'))

print df
print '---'
print df[:0]


data = pd.read_csv('./belt.csv')
runs = pd.read_csv('./runs.csv')

data['year'] = pd.Series(np.random.randn(len(data)))
data['week'] = pd.Series(np.random.randn(len(data)))

runs['year'] = pd.Series(np.random.randn(len(runs)))
runs['week'] = pd.Series(np.random.randn(len(runs)))

for i in range(len(data)):
    d = datetime.datetime.strptime((data['Date'][i]), "%d-%b-%y").date()
    data['year'][i] = d.isocalendar()[0]
    data['week'][i] = d.isocalendar()[1]

for i in range(len(runs)):
    d = datetime.datetime.strptime((runs['date'][i]), "%d/%m/%Y").date()
    runs['year'][i] = d.isocalendar()[0]
    runs['week'][i] = d.isocalendar()[1]

#asub2014 = data['year'] == 2014
#asub2014

runs.head()
# Out:
#      A  B  C  D
# aa   2  3  5  6
# bb  23  5  6  6
# cc  23  5  6  6
# dd  23  5  6  6
# ---
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []
# C:\Anaconda2\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
data['kminlast4weeks'] = pd.Series(np.random.randn(len(data)))

for i in range(len(data)):
    data['kminlast4weeks'][i] = 0
    if data['year'][i] > 2015:
        year = data['year'][i]
        week = data['week'][i]
        asubyear = runs['year'] == year
        asubweek = runs['week'] == week
        a=0
        b=0
        c=0
        
        a = runs[asubyear & asubweek]['Km run'].values[0]
        
        if week > 1:
            asubweek = runs['week'] == (week - 1)
            b = runs[asubyear & asubweek]['Km run'].values[0]
        if week > 2:
            asubweek = runs['week'] == (week - 2)
            c = runs[asubyear & asubweek]['Km run'].values[0]
        
        data['kminlast4weeks'][i] = (a+b+c)

#asubyear = runs['year'] == 2016
#asubweek = runs['week'] == 4
#print runs[asubyear & asubweek]['Km run'].values[0]
#print runs[asubyear]
data.head()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Anaconda2\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         Date  belt  navel  weight     Fat kg  Non Fat kg US Navy Fat %  \
# 0  11-Jan-14  94.0  88.00    78.0  14.638640   63.361360   18.76748673
# 1  21-Nov-14  97.0  91.00    83.0  17.390785   65.609215   20.95275321
# 2  21-Jan-16  88.8  85.00    78.0  12.828184   65.171816   16.44639018
# 3  28-Jan-16  86.0  79.75    77.6   9.313025   68.286975   12.00132125
# ...

# %%
plt.scatter('belt','kminlast4weeks',data=data)
plt.show()

# %%
struct_time = time.strptime("30 Nov 00", "%d %b %y")
struct_time
#datetime.datetime.strptime('24-05-2010', "%d-%m-%Y").date()
datetime.datetime.strptime('24-Jan-2010', "%d-%b-%Y").date()
# Out:
# datetime.date(2010, 1, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 7 columns):
# Date             49 non-null object
# belt             46 non-null float64
# navel            46 non-null float64
# weight           43 non-null float64
# Fat kg           44 non-null float64
# Non Fat kg       44 non-null float64
# US Navy Fat %    49 non-null object
# dtypes: float64(5), object(2)
# memory usage: 2.8+ KB

# %%
nonaData = data.dropna()
print nonaData.head()
plt.scatter(data.belt,data['navel'])
plt.show()
# Out:
#         Date  belt  navel  weight     Fat kg  Non Fat kg US Navy Fat %
# 0  11-Jan-14  94.0  88.00    78.0  14.638640   63.361360   18.76748673
# 1  21-Nov-14  97.0  91.00    83.0  17.390785   65.609215   20.95275321
# 2  21-Jan-16  88.8  85.00    78.0  12.828184   65.171816   16.44639018
# 3  28-Jan-16  86.0  79.75    77.6   9.313025   68.286975   12.00132125
# 4  29-Jan-16  85.0  79.00    77.3   8.750996   68.549004   11.32082299

# %%
'''plt.scatter(nonaData.belt,nonaData['Fat kg'])
plt.show()
plt.scatter(nonaData.belt,nonaData['weight'])
plt.show()
plt.scatter(nonaData.belt,nonaData['navel'])
plt.show()
'''
import seaborn as sns
sns.pairplot(data,x_vars=['Fat kg','weight','navel'],y_vars ='belt', size=5,aspect=0.7,kind='reg')

# %%
data.head()
# Out:
#         Date  belt  navel  weight     Fat kg  Non Fat kg US Navy Fat %
# 0  11-Jan-14  94.0  88.00    78.0  14.638640   63.361360   18.76748673
# 1  21-Nov-14  97.0  91.00    83.0  17.390785   65.609215   20.95275321
# 2  21-Jan-16  88.8  85.00    78.0  12.828184   65.171816   16.44639018
# 3  28-Jan-16  86.0  79.75    77.6   9.313025   68.286975   12.00132125
# 4  29-Jan-16  85.0  79.00    77.3   8.750996   68.549004   11.32082299
